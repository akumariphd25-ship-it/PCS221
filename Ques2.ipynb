# %%
import numpy as np

# %%
rows = 5
cols = 4

matrix = np.random.randint(0, 10, size=(rows, cols))
matrix
# Out:
# array([[9, 5, 9, 7],
#        [4, 0, 4, 9],
#        [5, 9, 1, 8],
#        [9, 0, 6, 7],
#        [7, 1, 5, 1]])

# %%
matrix[1:] = matrix[0]
matrix
# Out:
# array([[9, 5, 9, 7],
#        [9, 5, 9, 7],
#        [9, 5, 9, 7],
#        [9, 5, 9, 7],
#        [9, 5, 9, 7]])
