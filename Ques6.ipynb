# %%
matrix = (
    (1, 2, 3),
    (4, 5, 6),
    (7, 8, 9)
)

print("Matrix:")
for row in matrix:
    print(row)
# Out:
# Matrix:
# (1, 2, 3)
# (4, 5, 6)
# (7, 8, 9)

# %%
row_sums = tuple(sum(row) for row in matrix)

print("\nRow-wise sums:")
print(row_sums)
# Out:
# Row-wise sums:
# (6, 15, 24)
